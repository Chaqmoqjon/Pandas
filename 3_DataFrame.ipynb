# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaqmoqjon/Pandas/blob/main/3_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
uz_data = {
    'Yil'  : [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017],
    'Aholi' : [36.1, 35.5, 34.6, 34.0, 33.5, 32.9, 32.1, 30.5],
    'Temp' : [1.54, 1.55, 1.64, 1.53, 1.68, 1.57, 1.60, 1.55]
}

# %%
df = pd.DataFrame(uz_data)

# %%
df
# Out:
#     Yil  Aholi  Temp
# 0  2024   36.1  1.54
# 1  2023   35.5  1.55
# 2  2022   34.6  1.64
# 3  2021   34.0  1.53
# 4  2020   33.5  1.68
# 5  2019   32.9  1.57
# 6  2018   32.1  1.60
# 7  2017   30.5  1.55

# %%
df.shape
# Out:
# (8, 3)

# %%
df = pd.DataFrame(uz_data, columns=['Aholi', 'Temp', 'Yil']) # columlarni almashtirish

# %%
df
# Out:
#    Aholi  Temp   Yil
# 0   36.1  1.54  2024
# 1   35.5  1.55  2023
# 2   34.6  1.64  2022
# 3   34.0  1.53  2021
# 4   33.5  1.68  2020
# 5   32.9  1.57  2019
# 6   32.1  1.60  2018
# 7   30.5  1.55  2017

# %%
df = pd.DataFrame(uz_data, columns=['Aholi', 'Temp', 'Yil', 'YIM'], index=[20, '22', 'salom', -6, 2.6, 9, '-5.2', 8]) # Yo'q bo'lsa Null qaytaradi. Indeksga istalgan qiymatni bersa bo'ladi
df
# Out:
#        Aholi  Temp   Yil  YIM
# 20      36.1  1.54  2024  NaN
# 22      35.5  1.55  2023  NaN
# salom   34.6  1.64  2022  NaN
# -6      34.0  1.53  2021  NaN
# 2.6     33.5  1.68  2020  NaN
# 9       32.9  1.57  2019  NaN
# -5.2    32.1  1.60  2018  NaN
# 8       30.5  1.55  2017  NaN

# %%
aholi = df['Aholi']
aholi
# Out:
# 20       36.1
# 22       35.5
# salom    34.6
# -6       34.0
# 2.6      33.5
# 9        32.9
# -5.2     32.1
# 8        30.5
# Name: Aholi, dtype: float64

# %%
type(aholi)  #Series turida bo'ladi
# Out:
# pandas.core.series.Series

# %%
df.Yil  #method sifatida ham ishlatsa bo'ladi
# Out:
# 20       2024
# 22       2023
# salom    2022
# -6       2021
# 2.6      2020
# 9        2019
# -5.2     2018
# 8        2017
# Name: Yil, dtype: int64

# %%
df
# Out:
#        Aholi  Temp   Yil  YIM
# 20      36.1  1.54  2024  NaN
# 22      35.5  1.55  2023  NaN
# salom   34.6  1.64  2022  NaN
# -6      34.0  1.53  2021  NaN
# 2.6     33.5  1.68  2020  NaN
# 9       32.9  1.57  2019  NaN
# -5.2    32.1  1.60  2018  NaN
# 8       30.5  1.55  2017  NaN

# %%
df.YIM = 0
df
# Out:
#        Aholi  Temp   Yil  YIM
# 20      36.1  1.54  2024    0
# 22      35.5  1.55  2023    0
# salom   34.6  1.64  2022    0
# -6      34.0  1.53  2021    0
# 2.6     33.5  1.68  2020    0
# 9       32.9  1.57  2019    0
# -5.2    32.1  1.60  2018    0
# 8       30.5  1.55  2017    0

# %%
# 1 - usul
yim_val = pd.Series([1700, 1800, 2000, 1600], index=[9, 20, -6, 8])  # qiymatini o'zgartirish
df.YIM = yim_val
df
# Out:
#        Aholi  Temp   Yil     YIM
# 20      36.1  1.54  2024  1800.0
# 22      35.5  1.55  2023     NaN
# salom   34.6  1.64  2022     NaN
# -6      34.0  1.53  2021  2000.0
# 2.6     33.5  1.68  2020     NaN
# 9       32.9  1.57  2019  1700.0
# -5.2    32.1  1.60  2018     NaN
# 8       30.5  1.55  2017  1600.0

# %%
# 2 - usul
yim_val = [1700, 1800, 2000, 1600, 1500, 1650, 1800, 1700]  # o'lchami to'g'ri kelsa olaveradi
df.YIM = yim_val
df
# Out:
#        Aholi  Temp   Yil   YIM
# 20      36.1  1.54  2024  1700
# 22      35.5  1.55  2023  1800
# salom   34.6  1.64  2022  2000
# -6      34.0  1.53  2021  1600
# 2.6     33.5  1.68  2020  1500
# 9       32.9  1.57  2019  1650
# -5.2    32.1  1.60  2018  1800
# 8       30.5  1.55  2017  1700

# %%
df['1500+'] = df.YIM > 1500  # Agar YIM 1500 dan ko'p bo'lsa True aks holda False qaytar
df
# Out:
#        Aholi  Temp   Yil   YIM  1500+
# 20      36.1  1.54  2024  1700   True
# 22      35.5  1.55  2023  1800   True
# salom   34.6  1.64  2022  2000   True
# -6      34.0  1.53  2021  1600   True
# 2.6     33.5  1.68  2020  1500  False
# 9       32.9  1.57  2019  1650   True
# -5.2    32.1  1.60  2018  1800   True
# 8       30.5  1.55  2017  1700   True

# %%
del df['1500+']  #o'chirish

# %%
df
# Out:
#        Aholi  Temp   Yil   YIM
# 20      36.1  1.54  2024  1700
# 22      35.5  1.55  2023  1800
# salom   34.6  1.64  2022  2000
# -6      34.0  1.53  2021  1600
# 2.6     33.5  1.68  2020  1500
# 9       32.9  1.57  2019  1650
# -5.2    32.1  1.60  2018  1800
# 8       30.5  1.55  2017  1700

# %%
import pandas as pd
data_dav = {
    'Uzbekistan' : {2021:33.29, 2020:32.02,  2019:31.00, 2018:29.66, 2017:28.22},
    'Kazakhstan' : {2021:18.29, 2020:17.02,  2019:16.00, 2018:15.66, 2017:14.22, 2016:13.02}
}
df_dav = pd.DataFrame(data_dav)  # 2 qavatli dic
df_dav
# Out:
#       Uzbekistan  Kazakhstan
# 2021       33.29       18.29
# 2020       32.02       17.02
# 2019       31.00       16.00
# 2018       29.66       15.66
# 2017       28.22       14.22
# 2016         NaN       13.02

# %%
df_dav.head()
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021       33.29       18.29
# 2020       32.02       17.02
# 2019       31.00       16.00
# 2018       29.66       15.66
# 2017       28.22       14.22

# %%
df_dav.index.name = 'Yil'  # indeksni nom berish
df_dav
# Out:
#       Uzbekistan  Kazakhstan
# Yil
# 2021       33.29       18.29
# 2020       32.02       17.02
# 2019       31.00       16.00
# 2018       29.66       15.66
# 2017       28.22       14.22
# 2016         NaN       13.02

# %%
df_dav2 = pd.DataFrame(data_dav, index = [2017, 2019, 2021]) # kerakli ma'lumotlarini indekslarini beramiz
df_dav2
# Out:
#       Uzbekistan  Kazakhstan
# 2017       28.22       14.22
# 2019       31.00       16.00
# 2021       33.29       18.29

# %%
df_dav2.T  # Transpose orqali column va row larni almashtirish
# Out:
#              2017  2019   2021
# Uzbekistan  28.22  31.0  33.29
# Kazakhstan  14.22  16.0  18.29

# %%
arr = df_dav2.values  # qiymatlarini np.arrayga aylantirish

# %%
arr #np.array amallarni bajarish mumkin endi
# Out:
# array([[28.22, 14.22],
#        [31.  , 16.  ],
#        [33.29, 18.29]])

# %%
type(arr)
# Out:
# numpy.ndarray

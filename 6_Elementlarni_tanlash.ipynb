# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaqmoqjon/Pandas/blob/main/6_Elementlarni_tanlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
uz_data = {
    'Yil'  : [2024, 2023, 2022, 2021, 2020, 2019, 2018, 2013],
    'Aholi' : [36.1, 35.5, 34.6, 34.0, 33.5, 32.9, 32.1, 30.5],
    'Temp' : [1.54, 1.55, 1.64, 1.53, 1.68, 1.57, 1.60, 1.55],
     'Zichlik' : [76.1, 75.5, 74.6, 74.0, 73.5, 72.9, 72.1, 70.5]
}

df = pd.DataFrame(uz_data)
df.index = [24, 23, 22, 21, 20, 19, 18, 13]
df
# Out:
#      Yil  Aholi  Temp  Zichlik
# 24  2024   36.1  1.54     76.1
# 23  2023   35.5  1.55     75.5
# 22  2022   34.6  1.64     74.6
# 21  2021   34.0  1.53     74.0
# 20  2020   33.5  1.68     73.5
# 19  2019   32.9  1.57     72.9
# 18  2018   32.1  1.60     72.1
# 13  2013   30.5  1.55     70.5

# %%
data = df['Aholi']
data  #Series typeda
data[22]  # numpy.float64
data[[22]] #pandas.core.series.Series
# Out:
# 22    34.6
# Name: Aholi, dtype: float64

# %%
data[0:4]  #ma'lumotlarni kesib olish
# Out:
# 24    36.1
# 23    35.5
# 22    34.6
# 21    34.0
# Name: Aholi, dtype: float64

# %%
data[[24, 23, 22, 21]]  #ma'lumotlarni kesib olish
# Out:
# 24    36.1
# 23    35.5
# 22    34.6
# 21    34.0
# Name: Aholi, dtype: float64

# %%
obj  =pd.Series(np.arange(8.), index= ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
obj['a']
# Out:
# 0.0

# %%
obj[0:5]
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj['a' : 'e']
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj[[0, 3,4]]
# Out:
# <ipython-input-44-7bab7f48ea1e>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[[0, 3,4]]
# a    0.0
# d    3.0
# e    4.0
# dtype: float64

# %%
obj[['a', 'c', 'e']]
# Out:
# a    0.0
# c    2.0
# e    4.0
# dtype: float64

# %%
obj['a': 'c'] = 15
obj
# Out:
# a    15.0
# b    15.0
# c    15.0
# d     3.0
# e     4.0
# f     5.0
# g     6.0
# h     7.0
# dtype: float64

# %%
obj[obj < 15]
# Out:
# d    3.0
# e    4.0
# f    5.0
# g    6.0
# h    7.0
# dtype: float64

# %%
data = df[['Aholi']]  #Ikkitali  [[ ]] DataFrame olish uchun
data  #pandas.core.frame.DataFrame type
# Out:
#    Aholi
# 0   36.1
# 1   35.5
# 2   34.6
# 3   34.0
# 4   33.5
# 5   32.9
# 6   32.1
# 7   30.5

# %%
import pandas as pd
uz = {2020: 33.5, 2019: 32.9, 2018: 32.5, 2017: 31.9, 2016: 31.4, 2015: 30.9}
kz = {2020: 18.8, 2019: 18.3, 2018: 18.1, 2017: 18.1, 2016: 17.8, 2015: 17.6}
tj = {2020: 9.5, 2019: 9.3, 2018: 9.1, 2017: 8.9, 2016: 8.7, 2015: 8.5}
kg = {2020: 6.5, 2019: 6.4, 2018: 6.3, 2017: 6.2, 2016: 6.1, 2015: 6.0}
tr = {2020: 6.0, 2019: 5.9, 2018: 5.9, 2017: 5.8, 2016: 5.6, 2015: 5.6}

df = pd.DataFrame(
    {
        'Uzbekistan': uz,
        'Kazakhstan': kz,
        'Tajikistan': tj,
        'Kyrgyzstan': kg,
        'Turkmenistan': tr
    }
)
df
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        33.5        18.8         9.5         6.5           6.0
# 2019        32.9        18.3         9.3         6.4           5.9
# 2018        32.5        18.1         9.1         6.3           5.9
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df[['Uzbekistan']]  # [ ]  Series type. [[ ]] DataFrame type. Bular ustida turli hil amallar bajarilish uchun ishlatiladi. Farqi shunda
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5
# 2017        31.9
# 2016        31.4
# 2015        30.9

# %%
df['Uzbekistan']
# Out:
# 2020    33.5
# 2019    32.9
# 2018    32.5
# 2017    31.9
# 2016    31.4
# 2015    30.9
# Name: Uzbekistan, dtype: float64

# %%
df[['Uzbekistan', 'Tajikistan']]
# Out:
#       Uzbekistan  Tajikistan
# 2020        33.5         9.5
# 2019        32.9         9.3
# 2018        32.5         9.1
# 2017        31.9         8.9
# 2016        31.4         8.7
# 2015        30.9         8.5

# %%
df[3:]
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2017        31.9        18.1         8.9         6.2           5.8
# 2016        31.4        17.8         8.7         6.1           5.6
# 2015        30.9        17.6         8.5         6.0           5.6

# %%
df>10
# Out:
#       Uzbekistan  Kazakhstan  Tajikistan  Kyrgyzstan  Turkmenistan
# 2020        True        True       False       False         False
# 2019        True        True       False       False         False
# 2018        True        True       False       False         False
# 2017        True        True       False       False         False
# 2016        True        True       False       False         False
# 2015        True        True       False       False         False

# %%
dfuz = df[['Uzbekistan']] #O'zbekistonning ichidan aholisi 32 dan yuqori bo'lgan yillarni saralash
dfuz
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5
# 2017        31.9
# 2016        31.4
# 2015        30.9

# %%
dfuz[dfuz['Uzbekistan']>32]
# Out:
#       Uzbekistan
# 2020        33.5
# 2019        32.9
# 2018        32.5

# %%
df2 = df.transpose(copy=True) #Ustun va colum qiymatlarini o'zgartirish
df2
# Out:
#               2020  2019  2018  2017  2016  2015
# Uzbekistan    33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhstan    18.8  18.3  18.1  18.1  17.8  17.6
# Tajikistan     9.5   9.3   9.1   8.9   8.7   8.5
# Kyrgyzstan     6.5   6.4   6.3   6.2   6.1   6.0
# Turkmenistan   6.0   5.9   5.9   5.8   5.6   5.6

# %%
df2[df2[2015] > 6] # 2015-yilda aholisi 6 dan yuqorilar chiqsin
# Out:
#             2020  2019  2018  2017  2016  2015
# Uzbekistan  33.5  32.9  32.5  31.9  31.4  30.9
# Kazakhstan  18.8  18.3  18.1  18.1  17.8  17.6
# Tajikistan   9.5   9.3   9.1   8.9   8.7   8.5

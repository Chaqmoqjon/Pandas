# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaqmoqjon/Pandas/blob/main/15_Filtrlash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# Keyingi mashqlar uchun ma'lumotlarni Githubdan yuklab olamiz
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
FuelType = df['fuelType'].unique() #uniq lar ro'yxati
FuelType
# Out:
# array(['Petrol', 'Hybrid', 'Diesel', 'Other'], dtype=object)

# %%
df.value_counts('fuelType') # qiymatlarni sanash
# Out:
# fuelType
# Diesel    9187
# Petrol    3752
# Hybrid     173
# Other        7
# Name: count, dtype: int64

# %%
models = df['model'].unique() # o'zgaruvchiga saqlash
models.sort()
models
# Out:
# array([' A Class', ' B Class', ' C Class', ' CL Class', ' CLA Class',
#        ' CLC Class', ' CLK', ' CLS Class', ' E Class', ' G Class',
#        ' GL Class', ' GLA Class', ' GLB Class', ' GLC Class',
#        ' GLE Class', ' GLS Class', ' M Class', ' R Class', ' S Class',
#        ' SL CLASS', ' SLK', ' V Class', ' X-CLASS', '180', '200', '220',
#        '230'], dtype=object)

# %%
chose_model = [' SLK',' B Class' ]
filtr_model = df['model'].isin(chose_model) #mask yasab olish
filtr_model
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13114    False
# 13115     True
# 13116    False
# 13117    False
# 13118    False
# Name: model, Length: 13119, dtype: bool

# %%
df[filtr_model] #maskni ishlatish
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0           SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 12      B Class  2019  23750    Automatic      278   Diesel  145  55.4
# 15      B Class  2017  15890    Automatic    24841   Diesel  150  68.9
# 18      B Class  2017  17513    Automatic    14128   Diesel  150  68.9
# 40          SLK  2014  15990    Automatic    43955   Petrol  205  43.5
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 13033   B Class  2016  14599    Automatic    28156   Diesel   20  68.9
# 13073   B Class  2019  19350    Automatic    13674   Petrol  145  45.6
# 13108       SLK  2016  17499    Automatic    30128   Diesel   30  70.6
# 13111   B Class  2019  19344    Automatic    15257   Petrol  145  45.6
# 13115   B Class  2020  24699    Automatic     2500   Diesel  145  55.4
#
#        engineSize
# 0             1.8
# 12            2.0
# 15            1.5
# 18            2.1
# ...

# %%
df[df['fuelType'].isin(['Diesel', 'Petrol'])] # masksiz ishlatish
# Out:
#             model  year   price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005    5200    Automatic    63000   Petrol  325  32.1
# 2        SL CLASS  2016   49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016   61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016   73948    Automatic     4000   Petrol  325  30.1
# 5        SL CLASS  2011  149948    Automatic     3000   Petrol  570  21.4
# ...           ...   ...     ...          ...      ...      ...  ...   ...
# 13114     C Class  2020   35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020   24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019   30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019   37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019   54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 2             5.5
# 3             4.0
# ...

# %%
df[(df.year > 2018) & (df.price < 20000) & (df.mileage < 30000) & (df.transmission == 'Automatic')] #shartlar asosida chiqarish
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 89        A Class  2019  18118    Automatic    15561   Diesel  145  68.9
# 90        A Class  2019  17990    Automatic    14783   Diesel  145  65.7
# 93        A Class  2019  19840    Automatic     6781   Petrol  145  28.5
# 94        A Class  2019  18241    Automatic    15722   Diesel  145  65.7
# 95        A Class  2019  18141    Automatic    15689   Diesel  145  65.7
# 786       A Class  2019  18240    Automatic    15806   Diesel  145  68.9
# 889       A Class  2019  18190    Automatic    13264   Diesel  145  68.9
# 1095      A Class  2019  19840    Automatic    12066   Petrol  145  53.3
# 1950      A Class  2019  18760    Automatic    16060   Diesel  145  68.9
# 2393      A Class  2019  17895    Automatic    14757   Diesel  145  68.9
# 2400      A Class  2019  17702    Automatic    17843   Diesel  145  68.9
# 2402      A Class  2019  17728    Automatic    15025   Diesel  145  65.7
# ...
